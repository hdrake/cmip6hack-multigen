# %% [markdown]
# ### Modified by Brian Rose
#
# to use [intake-esm](https://intake-esm.readthedocs.io/en/latest/) for the data ingestion step (and hopefully be a bit more explicit and easier to generalize to other data)

# %%
import os
os.environ['NUMPY_EXPERIMENTAL_ARRAY_FUNCTION'] = '0'

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import xskillscore as xs
import xesmf as xe
import gcsfs
from tqdm.autonotebook import tqdm

from xhistogram.xarray import histogram

import intake
# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
import util 

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 6
# %config InlineBackend.figure_format = 'retina'
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tqdm/autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['stac-catalog', 'stac-collection', 'stac-item'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
# Cluster was created via the dask labextension
# Delete this cell and replace with a new one

# from dask.distributed import Client
# from dask_kubernetes import KubeCluster

# cluster = KubeCluster()
# cluster.adapt(minimum=1, maximum=20, interval='2s')
# client = Client(cluster)
# client

# %%
#  Here we will work with surface air temperature
varname = 'tas'

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_datastore("../catalogs/pangeo-cmip6.json")
col
# Out:
# pangeo-cmip6-ESM Collection with 28660 entries:
# 	> 10 activity_id(s)
#
# 	> 23 institution_id(s)
#
# 	> 48 source_id(s)
#
# 	> 29 experiment_id(s)
#
# 	> 86 member_id(s)
#
# 	> 23 table_id(s)
#
# 	> 190 variable_id(s)
#
# 	> 7 grid_label(s)
#
# 	> 28660 zstore(s)
#
# 	> 59 dcpp_init_year(s)

# %% [markdown]
# ## The task at hand
#
# - Loop through the `source_id` for `experiment_id == 'historical'`
# - For each model:
#     - select only a single ensemble member (at least for now)
#     - Take a slice `time=slice('1980', '2019')` and compute time average over that slice
#     - Regrid the `tas` data to a common grid
#     - drop redundant variables (like "height: 2m")
#     - concatenate to ensemble dataset along `ensemble` dimension

# %%
#  Define the common target grid axes
ds_out = xr.Dataset({'lat': (['lat'], np.arange(-88.5, 89.5, 2.)),
                     'lon': (['lon'], np.arange(0.5, 360., 2.)),
                    }
                   )

def regrid_to_common(ds, ds_out):
    """
    Regrid from rectilinear grid to common grid
    """
    regridder = xe.Regridder(ds, ds_out, 'bilinear',periodic=True, reuse_weights=True)
    return regridder(ds)

# %%
cat = col.search(experiment_id='historical', 
                 table_id='Amon', 
                 variable_id=varname,
                 member_id='r1i1p1f1'  # choose first ensemble member only (for now)
                )
cat.df
# Out:
#       activity_id       institution_id       source_id experiment_id  \
# 289          CMIP                  BCC     BCC-CSM2-MR    historical
# 552          CMIP                  BCC        BCC-ESM1    historical
# 827          CMIP                 CAMS     CAMS-CSM1-0    historical
# 2446         CMIP                CCCma         CanESM5    historical
# 5745         CMIP         E3SM-Project        E3SM-1-0    historical
# 5999         CMIP  EC-Earth-Consortium   EC-Earth3-Veg    historical
# 7339         CMIP                 IPSL    IPSL-CM6A-LR    historical
# 9575         CMIP                MIROC          MIROC6    historical
# 11166        CMIP                  MRI      MRI-ESM2-0    historical
# 11465        CMIP            NASA-GISS  GISS-E2-1-G-CC    historical
# 11807        CMIP            NASA-GISS     GISS-E2-1-G    historical
# 12628        CMIP            NASA-GISS     GISS-E2-1-H    historical
# 13324        CMIP                 NCAR     CESM2-WACCM    historical
# 14513        CMIP                 NCAR           CESM2    historical
# 16485        CMIP            NOAA-GFDL        GFDL-CM4    historical
# 16673        CMIP            NOAA-GFDL       GFDL-ESM4    historical
# 16824        CMIP                NUIST           NESM3    historical
# 17058        CMIP                  SNU     SAM0-UNICON    historical
# 17199        CMIP                   UA      MCM-UA-1-0    historical
#
#       member_id table_id variable_id grid_label  \
# 289    r1i1p1f1     Amon         tas         gn
# 552    r1i1p1f1     Amon         tas         gn
# 827    r1i1p1f1     Amon         tas         gn
# 2446   r1i1p1f1     Amon         tas         gn
# 5745   r1i1p1f1     Amon         tas         gr
# 5999   r1i1p1f1     Amon         tas         gr
# 7339   r1i1p1f1     Amon         tas         gr
# 9575   r1i1p1f1     Amon         tas         gn
# 11166  r1i1p1f1     Amon         tas         gn
# 11465  r1i1p1f1     Amon         tas         gn
# 11807  r1i1p1f1     Amon         tas         gn
# 12628  r1i1p1f1     Amon         tas         gn
# 13324  r1i1p1f1     Amon         tas         gn
# 14513  r1i1p1f1     Amon         tas         gn
# 16485  r1i1p1f1     Amon         tas        gr1
# 16673  r1i1p1f1     Amon         tas        gr1
# 16824  r1i1p1f1     Amon         tas         gn
# 17058  r1i1p1f1     Amon         tas         gn
# 17199  r1i1p1f1     Amon         tas         gn
#
#                                                   zstore  dcpp_init_year
# 289    gs://cmip6/CMIP/BCC/BCC-CSM2-MR/historical/r1i...             NaN
# 552    gs://cmip6/CMIP/BCC/BCC-ESM1/historical/r1i1p1...             NaN
# 827    gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 2446   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 5745   gs://cmip6/CMIP/E3SM-Project/E3SM-1-0/historic...             NaN
# 5999   gs://cmip6/CMIP/EC-Earth-Consortium/EC-Earth3-...             NaN
# 7339   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9575   gs://cmip6/CMIP/MIROC/MIROC6/historical/r1i1p1...             NaN
# 11166  gs://cmip6/CMIP/MRI/MRI-ESM2-0/historical/r1i1...             NaN
# 11465  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G-CC/histo...             NaN
# 11807  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-G/historic...             NaN
# 12628  gs://cmip6/CMIP/NASA-GISS/GISS-E2-1-H/historic...             NaN
# 13324  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r1...             NaN
# 14513  gs://cmip6/CMIP/NCAR/CESM2/historical/r1i1p1f1...             NaN
# 16485  gs://cmip6/CMIP/NOAA-GFDL/GFDL-CM4/historical/...             NaN
# 16673  gs://cmip6/CMIP/NOAA-GFDL/GFDL-ESM4/historical...             NaN
# 16824  gs://cmip6/CMIP/NUIST/NESM3/historical/r1i1p1f...             NaN
# 17058  gs://cmip6/CMIP/SNU/SAM0-UNICON/historical/r1i...             NaN
# 17199  gs://cmip6/CMIP/UA/MCM-UA-1-0/historical/r1i1p...             NaN

# %% [markdown]
# ### Loading data
#
# `intake-esm` enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) format and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user.
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 19 group(s)

# %%
ds = dset_dict['CMIP.BCC.BCC-CSM2-MR.historical.Amon.gn']
if ('longitude' in ds.dims) and ('latitude' in ds.dims):
    ds = ds.rename({'longitude':'lon', 'latitude': 'lat'})
ds = xr.decode_cf(ds)  # ensures that time is consistent across each dataset

# %%
ensdict = {}
for key, ds in tqdm(dset_dict.items()):
    print(key)
    # rename spatial dimensions if necessary
    if ('longitude' in ds.dims) and ('latitude' in ds.dims):
        ds = ds.rename({'longitude':'lon', 'latitude': 'lat'})
    ds = xr.decode_cf(ds)
    # take 1980-2019 mean
    timeave = ds.sel(time=slice('1980', '2019')).mean(dim='time')
    # regrid to common 1deg by 1deg grid
    ds_new = regrid_to_common(timeave[varname], ds_out)
    ds_new.attrs['name'] = ds.attrs['source_id']
    # drop redundant variables (like "height: 2m")
    for coord in ds_new.coords:
        if coord not in ['lat','lon']:
            ds_new = ds_new.drop(coord)
    # Add ensemble as new dimension
    ds_new = ds_new.expand_dims({'ensemble': np.array([ds_new.attrs['name']])}, 0)
    ensdict[key] = ds_new  # add this to the dictionary
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# CMIP.BCC.BCC-CSM2-MR.historical.Amon.gn
# Reuse existing file: bilinear_160x320_89x180_peri.nc
# CMIP.BCC.BCC-ESM1.historical.Amon.gn
# Reuse existing file: bilinear_64x128_89x180_peri.nc
# CMIP.CAMS.CAMS-CSM1-0.historical.Amon.gn
# Reuse existing file: bilinear_160x320_89x180_peri.nc
# CMIP.CCCma.CanESM5.historical.Amon.gn
# Reuse existing file: bilinear_64x128_89x180_peri.nc
# CMIP.E3SM-Project.E3SM-1-0.historical.Amon.gr
# Reuse existing file: bilinear_180x360_89x180_peri.nc
# CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.Amon.gr
# Reuse existing file: bilinear_256x512_89x180_peri.nc
# CMIP.IPSL.IPSL-CM6A-LR.historical.Amon.gr
# Reuse existing file: bilinear_143x144_89x180_peri.nc
# CMIP.MIROC.MIROC6.historical.Amon.gn
# Reuse existing file: bilinear_128x256_89x180_peri.nc
# CMIP.MRI.MRI-ESM2-0.historical.Amon.gn
# Reuse existing file: bilinear_160x320_89x180_peri.nc
# CMIP.NASA-GISS.GISS-E2-1-G.historical.Amon.gn
# Reuse existing file: bilinear_90x144_89x180_peri.nc
# CMIP.NASA-GISS.GISS-E2-1-G-CC.historical.Amon.gn
# Reuse existing file: bilinear_90x144_89x180_peri.nc
# CMIP.NASA-GISS.GISS-E2-1-H.historical.Amon.gn
# Reuse existing file: bilinear_90x144_89x180_peri.nc
# CMIP.NCAR.CESM2.historical.Amon.gn
# Reuse existing file: bilinear_192x288_89x180_peri.nc
# CMIP.NCAR.CESM2-WACCM.historical.Amon.gn
# Reuse existing file: bilinear_192x288_89x180_peri.nc
# CMIP.NOAA-GFDL.GFDL-CM4.historical.Amon.gr1
# Reuse existing file: bilinear_180x288_89x180_peri.nc
# CMIP.NOAA-GFDL.GFDL-ESM4.historical.Amon.gr1
# Reuse existing file: bilinear_180x288_89x180_peri.nc
# CMIP.NUIST.NESM3.historical.Amon.gn
# Reuse existing file: bilinear_96x192_89x180_peri.nc
# CMIP.SNU.SAM0-UNICON.historical.Amon.gn
# Reuse existing file: bilinear_192x288_89x180_peri.nc
# CMIP.UA.MCM-UA-1-0.historical.Amon.gn
# Reuse existing file: bilinear_80x96_89x180_peri.nc

# %%
ens = xr.concat([ds for name, ds in ensdict.items()], dim='ensemble')

# %%
# Use multi-model mean as temporary stand-in for observations
obs = ens.mean(dim='ensemble').compute()

# %%
# Plot anomalies with respect to observations (temporarily, actually multi-model mean)
q = (ens-obs).plot(x='lon', y='lat', col='ensemble', col_wrap=6)
# How to change color bar limits?

# %%
# Calculate skill of each model run relative to observations
# Note: currently the multi-model mean is a temporary stand-in for observations.
ens.attrs['rmse'] = {}
ens.attrs['mae'] = {}
for ensemble in tqdm(ens.ensemble):
    ds = ens.sel(ensemble=ensemble)
    ens.attrs['rmse'][str(ensemble.values)] = xs.rmse(obs, ds, ['lat', 'lon']).values
    ens.attrs['mae'][str(ensemble.values)] = xs.mae(obs, ds, ['lat', 'lon']).values
ens.attrs
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# {'regrid_method': 'bilinear',
#  'rmse': {'BCC-CSM2-MR': array([1.5949034]),
#   'BCC-ESM1': array([2.14519597]),
#   'CAMS-CSM1-0': array([2.08647741]),
#   'CanESM5': array([1.98267362]),
#   'E3SM-1-0': array([1.57802948]),
#   'EC-Earth3-Veg': array([2.29569208]),
#   'IPSL-CM6A-LR': array([2.08302541]),
#   'MIROC6': array([3.07966749]),
#   'MRI-ESM2-0': array([1.60356526]),
#   'GISS-E2-1-G': array([1.73320223]),
#   'GISS-E2-1-G-CC': array([1.64569449]),
#   'GISS-E2-1-H': array([1.49753984]),
#   'CESM2': array([1.50586351]),
#   'CESM2-WACCM': array([1.37434205]),
#   'GFDL-CM4': array([1.54585143]),
#   'GFDL-ESM4': array([1.32098108]),
#   'NESM3': array([1.40204691]),
#   'SAM0-UNICON': array([2.43313673]),
#   'MCM-UA-1-0': array([2.17375472])},
#  'mae': {'BCC-CSM2-MR': array([1.2936084]),
#   'BCC-ESM1': array([1.70253069]),
#   'CAMS-CSM1-0': array([1.44696864]),
#   'CanESM5': array([1.36371911]),
#   'E3SM-1-0': array([1.19123995]),
#   'EC-Earth3-Veg': array([1.57567494]),
#   'IPSL-CM6A-LR': array([1.47969793]),
#   'MIROC6': array([2.13524004]),
#   'MRI-ESM2-0': array([1.25449451]),
#   'GISS-E2-1-G': array([1.2332175]),
#   'GISS-E2-1-G-CC': array([1.19004076]),
#   'GISS-E2-1-H': array([1.02142311]),
#   'CESM2': array([1.16719594]),
#   'CESM2-WACCM': array([1.05344951]),
#   'GFDL-CM4': array([1.30763839]),
#   'GFDL-ESM4': array([0.96561075]),
#   'NESM3': array([1.03318965]),
#   'SAM0-UNICON': array([1.61824512]),
#   'MCM-UA-1-0': array([1.51895452])}}

# %%
plt.plot(list(ens.attrs['rmse'].values()),'C0o')
plt.xticks(np.arange(len(ens.attrs['rmse'].keys())),list(ens.attrs['rmse'].keys()),rotation=90)
plt.ylabel('Root-Mean Square Error [K]')
plt.ylim([0,4.25])
# Out:
# (0, 4.25)
